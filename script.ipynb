# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv('./MICRODADOS.csv', encoding='latin1', sep=';')
dados.head()
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_18288\2217406449.py:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('./MICRODADOS.csv', encoding='latin1', sep=';')
#   DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 0      2023-03-22   2023-03-22      2023-03-19               NaN
# 1      2023-03-22   2023-03-22      2023-03-20               NaN
# 2      2023-03-22   2023-03-22      2023-03-17               NaN
# 3      2023-03-22   2023-03-22      2023-03-19               NaN
# 4      2023-03-22   2023-03-22      2023-03-19               NaN
#
#   DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# 0                   NaN                 NaN                    NaN
# 1            2023-03-22                 NaN                    NaN
# 2            2023-03-22                 NaN                    NaN
# 3            2023-03-22                 NaN                    NaN
# ...

# %%
query = '(Municipio=="CARIACICA" & ComorbidadeTabagismo=="Sim") & (DataObito >= "2020" & Evolucao == "Óbito pelo COVID-19")'
resultado = dados.query(query)
resultado[['Municipio', 'Bairro', 'Classificacao', 'ComorbidadeTabagismo', 'DataObito', 'Evolucao']]
# Out:
#          Municipio            Bairro Classificacao ComorbidadeTabagismo  \
# 113899   CARIACICA            PROLAR   Confirmados                  Sim
# 683393   CARIACICA    CARIACICA SEDE   Confirmados                  Sim
# 798485   CARIACICA          TABAJARA   Confirmados                  Sim
# 810188   CARIACICA    VILA PRUDÊNCIO   Confirmados                  Sim
# 962995   CARIACICA       BELA AURORA   Confirmados                  Sim
# ...            ...               ...           ...                  ...
# 4723822  CARIACICA          ITAQUARI   Confirmados                  Sim
# 4724292  CARIACICA      SÃO BENEDITO   Confirmados                  Sim
# 4728797  CARIACICA        ITAPEMIRIM   Confirmados                  Sim
# 4729388  CARIACICA     VALE DOS REIS   Confirmados                  Sim
# 4739258  CARIACICA  PORTO DE SANTANA   Confirmados                  Sim
#
#           DataObito             Evolucao
# 113899   2023-01-10  Óbito pelo COVID-19
# ...
